# %%
import requests
from bs4 import BeautifulSoup
webpage=requests.get("https://www.daangn.com/hot_articles")

soup=BeautifulSoup(webpage.content, "html.parser", from_encoding='utf-8')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>
# <link href="https://www.daangn.com/hot_articles" rel="canonical"/>
# <title>당근마켓 - 중고거래는 당근마켓!</title>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." name="description"/>
# <meta content="https://www.daangn.com/hot_articles" property="og:url"/>
# <meta content="당근마켓 - 중고거래는 당근마켓!" property="og:title"/>
# <meta content="당근마켓에서 거래되는 인기 중고 매물을 소개합니다. 지금 당근마켓에서 거래되고 있는 다양한 매물을 구경해보세요." property="og:description"/>
# <meta content="당근마켓" property="og:site_name"/>
# <meta content="https://www.daangn.com/images/meta_hot_kr.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="1463621440622064" property="fb:app_id"/>
# ...

# %%
soup.find('h1')
# Out:
# <h1 id="fixed-bar-logo-title">
# <a href="https://www.daangn.com/">
# <span class="sr-only">당근마켓</span>
# <img alt="당근마켓" class="fixed-logo" src="https://d1unjqcospf8gs.cloudfront.net/assets/home/base/header/logo-basic-00b7e471b721ce9db8b0758c05a84684413c8aef1ad54caa0f3fcbe7328c947f.svg"/>
# </a> </h1>

# %%
soup.find('h1',{'class': 'head-title'})
# Out:
# <h1 class="head-title" id="hot-articles-head-title">
#
#
#     인기 중고 매물
#   </h1>

# %%
soup.find_all('h2',{'class': 'card-title'})
# Out:
# [<h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">위닉스 제습기</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">전자렌지 판매합니드</h2>,
#  <h2 class="card-title">제습기 무료드림</h2>,
#  <h2 class="card-title">엘지 제습기</h2>,
#  <h2 class="card-title">이사가면서 냉장고 내놓습니다~ 깨끗하게 새것처럼 사용했구요~ 상태 아주 좋습니다~ 냉장하단은 김치냉장고로 되어있어요</h2>,
#  <h2 class="card-title">위닉스 제습기16L</h2>,
#  <h2 class="card-title">맥스포츠 캠핑용 롤테이블 의자 세트</h2>,
#  <h2 class="card-title">전자렌지</h2>,
#  <h2 class="card-title">위니아 제습기(일등급16L)</h2>,
#  <h2 class="card-title">캠핑의자</h2>,
#  <h2 class="card-title">중고 자전거 판매 합니다.</h2>,
#  <h2 class="card-title">한일제습기</h2>,
#  <h2 class="card-title">3단 우드쉘프 캠핑검반 감성 나무선반 판매해요</h2>,
#  <h2 class="card-title">제습기</h2>,
#  <h2 class="card-title">캠핑용침낭</h2>,
#  <h2 class="card-title">추천)삼성전자 전자렌지판매해요!!</h2>,
#  <h2 class="card-title">휘센 제습기 </h2>,
#  <h2 class="card-title">가게정리로 선반 &amp; 화분 판매해요</h2>,
#  <h2 class="card-title">압력솥</h2>,
#  <h2 class="card-title">냉동고 판매</h2>,
# ...

# %%
data=soup.find_
